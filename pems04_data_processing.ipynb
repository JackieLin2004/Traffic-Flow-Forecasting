# %%
import numpy as np
import pandas as pd

# 读取 .npz 文件
npz_file = np.load('./data/PEMS04/PEMS04.npz')

# 获取三维数组（假设数组的名字是 'arr_0'，根据实际情况调整）
array = npz_file['data']

# 将三维数组展平成二维数组
reshaped_array = array.reshape(-1, 3)

# 使用 pandas 将二维数组写入 CSV 文件
df = pd.DataFrame(reshaped_array, columns=['flow', 'occupy', 'speed'])
df.to_csv('./PEMS04_npz.csv', index=False)

# %%
import numpy as np

data = np.load('./data/PEMS04/PEMS04.npz')
data['data']
data['data'].shape
# Out:
# (16992, 307, 3)

# %%
data['data']
# Out:
# array([[[6.20e+01, 7.70e-03, 6.79e+01],
#         [5.60e+01, 1.12e-02, 6.84e+01],
#         [9.00e+01, 1.43e-02, 6.82e+01],
#         ...,
#         [5.60e+01, 9.80e-03, 6.74e+01],
#         [4.80e+01, 7.80e-03, 6.95e+01],
#         [3.80e+01, 9.40e-03, 6.82e+01]],
#
#        [[6.10e+01, 7.40e-03, 6.73e+01],
#         [4.00e+01, 8.00e-03, 6.86e+01],
#         [9.40e+01, 1.56e-02, 6.78e+01],
#         ...,
#         [5.10e+01, 9.40e-03, 6.60e+01],
#         [3.00e+01, 5.00e-03, 6.91e+01],
#         [3.50e+01, 8.50e-03, 6.88e+01]],
#
#        [[7.10e+01, 9.30e-03, 6.84e+01],
#         [2.80e+01, 6.80e-03, 6.74e+01],
#         [7.90e+01, 1.22e-02, 6.87e+01],
#         ...,
#         [6.70e+01, 1.17e-02, 6.67e+01],
#         [3.10e+01, 5.30e-03, 6.88e+01],
#         [4.50e+01, 1.11e-02, 6.95e+01]],
#
#        ...,
#
#        [[6.60e+01, 8.90e-03, 6.78e+01],
#         [7.60e+01, 1.58e-02, 6.59e+01],
#         [7.70e+01, 1.82e-02, 6.40e+01],
#         ...,
#         [8.50e+01, 1.45e-02, 6.73e+01],
#         [5.80e+01, 1.00e-02, 6.93e+01],
#         [5.70e+01, 1.66e-02, 6.78e+01]],
#
#        [[7.70e+01, 1.03e-02, 6.74e+01],
#         [7.30e+01, 1.66e-02, 6.58e+01],
#         [9.60e+01, 2.01e-02, 6.31e+01],
#         ...,
#         [6.90e+01, 1.20e-02, 6.72e+01],
#         [5.20e+01, 8.70e-03, 6.93e+01],
#         [4.30e+01, 1.18e-02, 6.91e+01]],
#
#        [[7.40e+01, 9.80e-03, 6.70e+01],
#         [7.10e+01, 1.66e-02, 6.87e+01],
#         [6.40e+01, 1.27e-02, 6.52e+01],
#         ...,
#         [8.00e+01, 1.40e-02, 6.70e+01],
#         [7.80e+01, 1.44e-02, 6.96e+01],
#         [4.00e+01, 1.07e-02, 6.97e+01]]])

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./PEMS04_npz.csv')

# 输出行数
print(f"CSV 文件的行数: {len(df)}")
# Out:
# CSV 文件的行数: 5216544

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./PEMS04_npz.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
first_row = df.iloc[0]

print("CSV 文件的第 1 行数据:")
print(first_row)
# Out:
# CSV 文件的第 1 行数据:
# flow      62.0000
# occupy     0.0077
# speed     67.9000
# Name: 0, dtype: float64

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./PEMS04_npz.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[5216543]

print("CSV 文件的第 1 行数据:")
print(row)
# Out:
# CSV 文件的第 1 行数据:
# flow      40.0000
# occupy     0.0107
# speed     69.7000
# Name: 5216543, dtype: float64

# %%
import numpy as np

data = np.load('./data/PEMS04/PEMS04.npz')
data['data'].shape[0]
# Out:
# 16992

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./test_target.csv')

# 输出行数和列数
print(f"CSV 文件的行数: {df.shape[0]}")
print(f"CSV 文件的列数: {df.shape[1]}")
# Out:
# CSV 文件的行数: 1041958
# CSV 文件的列数: 12

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./test_target.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[0]

print("CSV 文件的第 1 行数据:")
print(row)
# Out:
# CSV 文件的第 1 行数据:
# test-1     54.0
# test-2     35.0
# test-3     48.0
# test-4     49.0
# test-5     68.0
# test-6     68.0
# test-7     70.0
# test-8     87.0
# test-9     55.0
# test-10    49.0
# test-11    45.0
# test-12    93.0
# Name: 0, dtype: float64

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./test_target.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[307]

print("CSV 文件的第 2 行数据:")
print(row)
# Out:
# CSV 文件的第 2 行数据:
# test-1     35.0
# test-2     48.0
# test-3     49.0
# test-4     68.0
# test-5     68.0
# test-6     70.0
# test-7     87.0
# test-8     55.0
# test-9     49.0
# test-10    45.0
# test-11    93.0
# test-12    92.0
# Name: 307, dtype: float64

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./astgcn_prediction.csv')

# 输出行数和列数
print(f"CSV 文件的行数: {df.shape[0]}")
print(f"CSV 文件的列数: {df.shape[1]}")
# Out:
# CSV 文件的行数: 1041958
# CSV 文件的列数: 12

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./astgcn_prediction.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[0]

print("CSV 文件的第 1 行数据:")
print(row)
# Out:
# CSV 文件的第 1 行数据:
# astgcn-1     52.039510
# astgcn-2     54.306480
# astgcn-3     56.633310
# astgcn-4     58.160420
# astgcn-5     59.330364
# astgcn-6     60.895844
# astgcn-7     62.032090
# astgcn-8     64.085830
# astgcn-9     65.978610
# astgcn-10    67.731540
# astgcn-11    69.041336
# astgcn-12    70.746380
# Name: 0, dtype: float64

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./astgcn_prediction.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[1]

print("CSV 文件的第 2 行数据:")
print(row)
# Out:
# CSV 文件的第 2 行数据:
# astgcn-1     73.972780
# astgcn-2     76.125980
# astgcn-3     78.136000
# astgcn-4     79.818140
# astgcn-5     81.487610
# astgcn-6     83.692085
# astgcn-7     85.740390
# astgcn-8     88.146720
# astgcn-9     90.276430
# astgcn-10    91.949490
# astgcn-11    93.253720
# astgcn-12    94.860320
# Name: 1, dtype: float64

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./mstgcn_prediction.csv')

# 输出行数和列数
print(f"CSV 文件的行数: {df.shape[0]}")
print(f"CSV 文件的列数: {df.shape[1]}")
# Out:
# CSV 文件的行数: 1041958
# CSV 文件的列数: 12

# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv('./mstgcn_prediction.csv')

# 查看第 1 行数据（注意：索引从 0 开始，所以使用 0 获取第 1 行）
row = df.iloc[0]

print("CSV 文件的第 1 行数据:")
print(row)
# Out:
# CSV 文件的第 1 行数据:
# astgcn-1     52.107190
# astgcn-2     58.642490
# astgcn-3     65.305410
# astgcn-4     70.383370
# astgcn-5     74.234290
# astgcn-6     76.528290
# astgcn-7     78.485600
# astgcn-8     81.939010
# astgcn-9     84.804390
# astgcn-10    87.863060
# astgcn-11    90.243390
# astgcn-12    93.661415
# Name: 0, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置Seaborn样式为dark-grid
sns.set(style="darkgrid")

# import matplotlib
# matplotlib.rcParams['agg.path.chunksize'] = 10000

# 读取三个CSV文件
df1 = pd.read_csv('./pems04_test_target.csv')
df2 = pd.read_csv('./pems04_astgcn_prediction.csv')
df3 = pd.read_csv('./pems04_mstgcn_prediction.csv')

# 定义一个函数，按照每307行求和，只取每个CSV的第一列
def sum_by_sensor(df, chunk_size=307):
    # 只取第一列数据
    col_data = df.iloc[:, 0]  # 只取第一列
    n_rows = col_data.shape[0]  # 数据的行数
    summed_data = []
    for i in range(0, n_rows, chunk_size):
        chunk_sum = col_data.iloc[i:i+chunk_size].sum()  # 每个传感器的数据求和
        summed_data.append(chunk_sum)
    return np.array(summed_data)

# 对每个CSV文件进行处理，按307行分块求和
summed_df1 = sum_by_sensor(df1)
summed_df2 = sum_by_sensor(df2)
summed_df3 = sum_by_sensor(df3)

# 创建一个新的绘图
plt.figure(figsize=(10, 6))

# 绘制每个数据集的第一列（每个文件的每个传感器的总和）折线图
plt.plot(summed_df1, label='origin-target', color='r', linewidth=3)
plt.plot(summed_df2, label='astgcn', color='b', linewidth=3)
plt.plot(summed_df3, label='mstgcn', color='g', linewidth=3)

# 添加图例
plt.legend()

# 设置标题和标签
plt.title('Comparison of Results in PEMS04', fontsize=14)
plt.xlabel('Times', fontsize=12)
plt.ylabel('Flow', fontsize=12)

# 保存图像到指定路径，分辨率为600
plt.savefig('./pems04_comparison.png', dpi=1000)

# 显示图像
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置Seaborn样式为dark-grid
sns.set(style="darkgrid")

# 读取三个CSV文件
df1 = pd.read_csv('./pems04_test_target.csv')
df2 = pd.read_csv('./pems04_astgcn_prediction.csv')
df3 = pd.read_csv('./pems04_mstgcn_prediction.csv')

# 定义一个函数，按照每307行求和，只取每个CSV的第一列
def sum_by_sensor(df, chunk_size=307):
    # 只取第一列数据
    col_data = df.iloc[:, 0]  # 只取第一列
    n_rows = col_data.shape[0]  # 数据的行数
    summed_data = []
    for i in range(0, n_rows, chunk_size):
        chunk_sum = col_data.iloc[i:i+chunk_size].sum()  # 每个传感器的数据求和
        summed_data.append(chunk_sum)
    return np.array(summed_data)

# 对每个CSV文件进行处理，按307行分块求和
summed_df1 = sum_by_sensor(df1)  # 原始目标值
summed_df2 = sum_by_sensor(df2)  # astgcn 的预测值
summed_df3 = sum_by_sensor(df3)  # mstgcn 的预测值

# 计算差值
diff_astgcn = summed_df2 - summed_df1  # astgcn 和目标值的差值
diff_mstgcn = summed_df3 - summed_df1  # mstgcn 和目标值的差值

# 创建一个新的绘图
plt.figure(figsize=(10, 6))

# 绘制差值图
plt.plot(diff_astgcn, label='Difference (astgcn - target)', color='b', linewidth=2, linestyle='--')
plt.plot(diff_mstgcn, label='Difference (mstgcn - target)', color='g', linewidth=2, linestyle='--')

# 添加零线（参考线）
plt.axhline(0, color='gray', linestyle=':', linewidth=1)

# 添加图例
plt.legend()

# 设置标题和标签
plt.title('Difference Comparison in PEMS04', fontsize=14)
plt.xlabel('Times', fontsize=12)
plt.ylabel('Difference in Flow', fontsize=12)

# 保存图像到指定路径，分辨率为600
plt.savefig('./pems04_difference_comparison.png', dpi=1000)

# 显示图像
plt.show()
